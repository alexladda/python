# %%
import numpy as np

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
df = pd.read_csv('pandas-passengers.csv')

# %%
df['Age'].hist()
# Out:
# <AxesSubplot:>

# %%
df['Fare'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
df['Age'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[['Age', 'Fare']].plot.area(alpha=0.5,figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
df.plot.line(x='PassengerId', y='Fare', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='PassengerId'>

# %%
df
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
df.plot.scatter(x='PassengerId', y='Age', c='Pclass', cmap='coolwarm', s=df['Pclass']*50 ,figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Age'>

# %%
df_t = pd.DataFrame(data = np.random.randn(30,2), index = pd.date_range('2020-01-01', '2020-01-30'), columns =['A','B'])

# %%
df_t
# Out:
#                    A         B
# 2020-01-01 -0.553651  1.476166
# 2020-01-02  0.556090  0.674618
# 2020-01-03  1.359611  0.045575
# 2020-01-04  0.645611  0.153571
# 2020-01-05  0.091376  0.393824
# 2020-01-06  0.539630 -0.706127
# 2020-01-07 -0.877194  0.822213
# 2020-01-08  1.272066  0.134641
# 2020-01-09  0.336195 -0.438678
# 2020-01-10  2.057697 -0.118594
# 2020-01-11  0.109484 -0.698104
# 2020-01-12  0.480446 -0.207021
# 2020-01-13  0.625695 -0.899249
# 2020-01-14  0.114733 -2.508538
# 2020-01-15 -0.539438  1.647784
# 2020-01-16  0.587608 -0.878405
# 2020-01-17 -0.059729 -0.374050
# 2020-01-18 -1.376423 -0.439510
# 2020-01-19 -1.935523  0.029879
# 2020-01-20 -1.691369 -0.355493
# 2020-01-21  0.757493 -0.071302
# 2020-01-22  0.594129 -1.311815
# 2020-01-23  0.736259  0.448156
# 2020-01-24  1.182219 -0.253336
# 2020-01-25 -0.200736 -0.656751
# 2020-01-26  1.342618 -0.174527
# 2020-01-27 -0.354281 -1.471289
# 2020-01-28  1.387053 -0.901332
# 2020-01-29 -0.551392  0.409913
# ...

# %%
df_t.plot.bar(figsize=(15,5))
# Out:
# <AxesSubplot:>

# %%
df_t.hist()
# Out:
# array([[<AxesSubplot:title={'center':'A'}>,
#         <AxesSubplot:title={'center':'B'}>]], dtype=object)

# %%
df_t.plot.box()
# Out:
# <AxesSubplot:>

# %%
df_t.plot.hexbin('A', 'B', gridsize=10)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df_t.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df_t.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
